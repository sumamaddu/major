# %% [markdown]
# <a href="https://colab.research.google.com/github/sumamaddu/major/blob/main/Copy_of_vgg16_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Install required libraries (installing tensorflow-gpu if available)
try:
    import tensorflow as tf
    # Check for GPU availability
    if len(tf.config.list_physical_devices('GPU')) > 0:
        print("GPU detected. Using tensorflow-gpu.")
        # !pip install tensorflow-gpu scikit-learn matplotlib
    else:
        print("No GPU detected. Using regular tensorflow.")
        # !pip install tensorflow scikit-learn matplotlib
except:
    print("Error with tensorflow. Using regular tensorflow.")
    # !pip install tensorflow scikit-learn matplotlib

import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import numpy as np
import os
import matplotlib.pyplot as plt

# Data and model parameters
IMG_HEIGHT, IMG_WIDTH = 224, 224
BATCH_SIZE = 32 # You can try 64 if your GPU has enough memory
EPOCHS = 50

# Corrected Data Paths
TRAIN_DIR = "/content/drive/MyDrive/Final_ds-20241211T160515Z-001/Final_ds/train"
TEST_DIR = "/content/drive/MyDrive/Final_ds-20241211T160515Z-001/Final_ds/test"
MODEL_DIR = "/content/drive/MyDrive/model"

os.makedirs(MODEL_DIR, exist_ok=True)

# --- Optimized Data Loading using tf.data ---
def preprocess_image(image, label):
    image = tf.image.resize(image, [IMG_HEIGHT, IMG_WIDTH])
    image = image / 255.0  # Rescale
    return image, label

train_dataset = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    labels='inferred',
    label_mode='categorical',
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    validation_split=0.2,
    subset='training',
    seed=42
)
validation_dataset = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    labels='inferred',
    label_mode='categorical',
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    validation_split=0.2,
    subset='validation',
    seed=42
)
test_dataset = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR,
    labels='inferred',
    label_mode='categorical',
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    shuffle=False # No need to shuffle test data
)

# Get class names before applying prefetch
class_names = train_dataset.class_names  # Store class names here

AUTOTUNE = tf.data.AUTOTUNE #Use AUTOTUNE for optimal performance
train_dataset = train_dataset.map(preprocess_image, num_parallel_calls=AUTOTUNE).cache().prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.map(preprocess_image, num_parallel_calls=AUTOTUNE).cache().prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.map(preprocess_image, num_parallel_calls=AUTOTUNE).cache().prefetch(buffer_size=AUTOTUNE)

# --- End of Optimized Data Loading ---

# VGG16 with FNN (Improved Architecture)
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))
for layer in base_model.layers:
    layer.trainable = False

x = base_model.output
x = Flatten()(x)
x = Dense(1024, activation='relu')(x)  # Reduced Dense layer size
x = BatchNormalization()(x)  # Added Batch Normalization
x = Dropout(0.5)(x)
num_classes = len(class_names)  # Access class_names here
predictions = Dense(num_classes, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=predictions)

# --- Mixed Precision Training (if GPU is available) ---
try:
    # Enable mixed precision training
    tf.keras.mixed_precision.set_global_policy('mixed_float16')
    print("Mixed precision training enabled.")
except Exception as e:
    print(f"Could not enable mixed precision: {e}")

# --- End of Mixed Precision Training ---

# Compile
opt = Adam(learning_rate=0.00001)  # Lowered learning rate further
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# Callbacks (Improved Callbacks)
checkpoint_path = os.path.join(MODEL_DIR, "osteoporosis_model.keras")
checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
early = EarlyStopping(monitor='val_accuracy', patience=15, verbose=1, mode='max', restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-6, verbose=1)

# Train (using tf.data datasets)
history = model.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=validation_dataset,
    callbacks=[checkpoint, early, reduce_lr]
)

# Evaluate the model
loss, accuracy = model.evaluate(test_dataset)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")

# Save class names
np.save(os.path.join(MODEL_DIR, "class_names.npy"), class_names)

# Plot Training History
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(len(acc))

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# GPU detected. Using tensorflow-gpu.
# Collecting tensorflow-gpu
#   Using cached tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Found 1447 files belonging to 2 classes.
# Using 1158 files for training.
# Found 1447 files belonging to 2 classes.
# Using 289 files for validation.
# Found 209 files belonging to 2 classes.
# Mixed precision training enabled.
# Epoch 1/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.5448 - loss: 0.9970
# Epoch 1: val_accuracy improved from -inf to 0.49481, saving model to /content/drive/MyDrive/model/osteoporosis_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 35s 483ms/step - accuracy: 0.5464 - loss: 0.9932 - val_accuracy: 0.4948 - val_loss: 0.8361 - learning_rate: 1.0000e-05
# Epoch 2/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7998 - loss: 0.4315
# Epoch 2: val_accuracy improved from 0.49481 to 0.50865, saving model to /content/drive/MyDrive/model/osteoporosis_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 16s 228ms/step - accuracy: 0.8006 - loss: 0.4306 - val_accuracy: 0.5087 - val_loss: 0.7511 - learning_rate: 1.0000e-05
# Epoch 3/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8770 - loss: 0.2760
# Epoch 3: val_accuracy improved from 0.50865 to 0.59862, saving model to /content/drive/MyDrive/model/osteoporosis_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 10s 228ms/step - accuracy: 0.8770 - loss: 0.2761 - val_accuracy: 0.5986 - val_loss: 0.5877 - learning_rate: 1.0000e-05
# Epoch 4/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9238 - loss: 0.1903
# Epoch 4: val_accuracy improved from 0.59862 to 0.79931, saving model to /content/drive/MyDrive/model/osteoporosis_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 8s 229ms/step - accuracy: 0.9233 - loss: 0.1912 - val_accuracy: 0.7993 - val_loss: 0.4184 - learning_rate: 1.0000e-05
# Epoch 5/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9483 - loss: 0.1443
# Epoch 5: val_accuracy improved from 0.79931 to 0.83045, saving model to /content/drive/MyDrive/model/osteoporosis_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 10s 285ms/step - accuracy: 0.9480 - loss: 0.1449 - val_accuracy: 0.8304 - val_loss: 0.3561 - learning_rate: 1.0000e-05
# Epoch 6/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9581 - loss: 0.1148
# Epoch 6: val_accuracy improved from 0.83045 to 0.91003, saving model to /content/drive/MyDrive/model/osteoporosis_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 172ms/step - accuracy: 0.9576 - loss: 0.1161 - val_accuracy: 0.9100 - val_loss: 0.2726 - learning_rate: 1.0000e-05
# Epoch 7/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9536 - loss: 0.1134
# Epoch 7: val_accuracy did not improve from 0.91003
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9536 - loss: 0.1136 - val_accuracy: 0.8997 - val_loss: 0.2686 - learning_rate: 1.0000e-05
# Epoch 8/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9806 - loss: 0.0748
# Epoch 8: val_accuracy improved from 0.91003 to 0.93080, saving model to /content/drive/MyDrive/model/osteoporosis_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 9s 250ms/step - accuracy: 0.9807 - loss: 0.0749 - val_accuracy: 0.9308 - val_loss: 0.1862 - learning_rate: 1.0000e-05
# Epoch 9/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9803 - loss: 0.0664
# Epoch 9: val_accuracy improved from 0.93080 to 0.94464, saving model to /content/drive/MyDrive/model/osteoporosis_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 171ms/step - accuracy: 0.9800 - loss: 0.0671 - val_accuracy: 0.9446 - val_loss: 0.1658 - learning_rate: 1.0000e-05
# Epoch 10/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9785 - loss: 0.0606
# Epoch 10: val_accuracy improved from 0.94464 to 0.95848, saving model to /content/drive/MyDrive/model/osteoporosis_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - accuracy: 0.9786 - loss: 0.0607 - val_accuracy: 0.9585 - val_loss: 0.1369 - learning_rate: 1.0000e-05
# Epoch 11/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9896 - loss: 0.0470
# Epoch 11: val_accuracy improved from 0.95848 to 0.96194, saving model to /content/drive/MyDrive/model/osteoporosis_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 10s 171ms/step - accuracy: 0.9895 - loss: 0.0473 - val_accuracy: 0.9619 - val_loss: 0.1215 - learning_rate: 1.0000e-05
# Epoch 12/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9957 - loss: 0.0355
# Epoch 12: val_accuracy improved from 0.96194 to 0.96540, saving model to /content/drive/MyDrive/model/osteoporosis_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 9s 238ms/step - accuracy: 0.9956 - loss: 0.0358 - val_accuracy: 0.9654 - val_loss: 0.1167 - learning_rate: 1.0000e-05
# Epoch 13/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9914 - loss: 0.0387
# Epoch 13: val_accuracy did not improve from 0.96540
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9913 - loss: 0.0390 - val_accuracy: 0.9550 - val_loss: 0.1139 - learning_rate: 1.0000e-05
# Epoch 14/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9913 - loss: 0.0396
# Epoch 14: val_accuracy did not improve from 0.96540
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.9913 - loss: 0.0398 - val_accuracy: 0.9619 - val_loss: 0.1038 - learning_rate: 1.0000e-05
# Epoch 15/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9985 - loss: 0.0231
# Epoch 15: val_accuracy did not improve from 0.96540
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9985 - loss: 0.0234 - val_accuracy: 0.9619 - val_loss: 0.0997 - learning_rate: 1.0000e-05
# Epoch 16/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9913 - loss: 0.0313
# Epoch 16: val_accuracy did not improve from 0.96540
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.9914 - loss: 0.0313 - val_accuracy: 0.9654 - val_loss: 0.1029 - learning_rate: 1.0000e-05
# Epoch 17/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9945 - loss: 0.0224
# Epoch 17: val_accuracy did not improve from 0.96540
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9945 - loss: 0.0226 - val_accuracy: 0.9654 - val_loss: 0.0939 - learning_rate: 1.0000e-05
# Epoch 18/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9972 - loss: 0.0234
# Epoch 18: val_accuracy did not improve from 0.96540
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9972 - loss: 0.0236 - val_accuracy: 0.9619 - val_loss: 0.0986 - learning_rate: 1.0000e-05
# Epoch 19/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9965 - loss: 0.0213
# Epoch 19: val_accuracy did not improve from 0.96540
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.9965 - loss: 0.0215 - val_accuracy: 0.9619 - val_loss: 0.1023 - learning_rate: 1.0000e-05
# Epoch 20/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9962 - loss: 0.0225
# Epoch 20: val_accuracy did not improve from 0.96540
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.9962 - loss: 0.0225 - val_accuracy: 0.9654 - val_loss: 0.0936 - learning_rate: 1.0000e-05
# Epoch 21/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9976 - loss: 0.0161
# Epoch 21: val_accuracy did not improve from 0.96540
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9975 - loss: 0.0164 - val_accuracy: 0.9654 - val_loss: 0.0899 - learning_rate: 1.0000e-05
# Epoch 22/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9989 - loss: 0.0153
# Epoch 22: val_accuracy improved from 0.96540 to 0.96886, saving model to /content/drive/MyDrive/model/osteoporosis_model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 171ms/step - accuracy: 0.9988 - loss: 0.0155 - val_accuracy: 0.9689 - val_loss: 0.0905 - learning_rate: 1.0000e-05
# Epoch 23/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9990 - loss: 0.0128
# Epoch 23: val_accuracy did not improve from 0.96886
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9990 - loss: 0.0130 - val_accuracy: 0.9654 - val_loss: 0.0861 - learning_rate: 1.0000e-05
# Epoch 24/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9987 - loss: 0.0141
# Epoch 24: val_accuracy did not improve from 0.96886
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.9985 - loss: 0.0144 - val_accuracy: 0.9550 - val_loss: 0.0904 - learning_rate: 1.0000e-05
# Epoch 25/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0099
# Epoch 25: val_accuracy did not improve from 0.96886
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 0.9619 - val_loss: 0.0887 - learning_rate: 1.0000e-05
# Epoch 26/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0115
# Epoch 26: val_accuracy did not improve from 0.96886
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 0.9654 - val_loss: 0.0791 - learning_rate: 1.0000e-05
# Epoch 27/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0128
# Epoch 27: val_accuracy did not improve from 0.96886
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 1.0000 - loss: 0.0128 - val_accuracy: 0.9689 - val_loss: 0.0803 - learning_rate: 1.0000e-05
# Epoch 28/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0091
# Epoch 28: val_accuracy did not improve from 0.96886
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.9619 - val_loss: 0.0822 - learning_rate: 1.0000e-05
# Epoch 29/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0098
# Epoch 29: val_accuracy did not improve from 0.96886
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.9550 - val_loss: 0.0781 - learning_rate: 1.0000e-05
# Epoch 30/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0069
# Epoch 30: val_accuracy did not improve from 0.96886
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.9619 - val_loss: 0.0801 - learning_rate: 1.0000e-05
# Epoch 31/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9989 - loss: 0.0094
# Epoch 31: val_accuracy did not improve from 0.96886
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.9989 - loss: 0.0095 - val_accuracy: 0.9689 - val_loss: 0.0852 - learning_rate: 1.0000e-05
# Epoch 32/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0087
# Epoch 32: val_accuracy did not improve from 0.96886
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.9654 - val_loss: 0.0849 - learning_rate: 1.0000e-05
# Epoch 33/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9985 - loss: 0.0100
# Epoch 33: val_accuracy did not improve from 0.96886
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.9985 - loss: 0.0100 - val_accuracy: 0.9654 - val_loss: 0.0869 - learning_rate: 1.0000e-05
# Epoch 34/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9990 - loss: 0.0097
# Epoch 34: val_accuracy did not improve from 0.96886
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1e-06.
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9989 - loss: 0.0097 - val_accuracy: 0.9619 - val_loss: 0.0844 - learning_rate: 1.0000e-05
# Epoch 35/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0060
# Epoch 35: val_accuracy did not improve from 0.96886
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.9619 - val_loss: 0.0826 - learning_rate: 1.0000e-06
# Epoch 36/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0054
# Epoch 36: val_accuracy did not improve from 0.96886
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.9619 - val_loss: 0.0822 - learning_rate: 1.0000e-06
# Epoch 37/50
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0062
# Epoch 37: val_accuracy did not improve from 0.96886
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.9654 - val_loss: 0.0818 - learning_rate: 1.0000e-06
# Epoch 37: early stopping
# Restoring model weights from the end of the best epoch: 22.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 58s 8s/step - accuracy: 0.9846 - loss: 0.0653
# Test Loss: 0.0802
# Test Accuracy: 0.9713
